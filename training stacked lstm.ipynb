# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.autograd import Variable
from torchinfo import summary
from sklearn.preprocessing import MinMaxScaler

import joblib

torch.manual_seed(42)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cpu')

# %%
train_data=pd.read_csv('./assets/processed dataset/train dataset.csv')
validation_data=pd.read_csv('./assets/processed dataset/validation dataset.csv')

# %%
#Data scaling
scaler=MinMaxScaler()
normalized_train_data=scaler.fit_transform(train_data)
joblib.dump(scaler, "./assets/scaler.gz") 
print(normalized_train_data[0])
normalized_validation_data=scaler.transform(validation_data)
print(normalized_validation_data[0])
# Out:
# [0.52820513 0.24944321 0.22440945 0.26689478]
# [0.5025641  0.50556793 0.17847769 0.72668948]

# %%
#Prepearing X and Y for training and validation
# Setting THE SEQUENCE LENGTH 
seq_length=180
#initialized to a empty 1d list
X_train=[]
Y_train=[]
X_validate=[]
Y_validate=[]
for i in range(seq_length,train_data.shape[0]):
    #Data from 0 to 59TH index
    X_train.append(normalized_train_data[i-seq_length:i])
    #T2M AT THE 60TH index
    Y_train.append(normalized_train_data[i])

for i in range(seq_length,validation_data.shape[0]):
    #Data from 0 to 59TH index
    X_validate.append(normalized_validation_data[i-seq_length:i])
    #T2M AT THE 60TH index
    Y_validate.append(normalized_validation_data[i])

# converting into numpy arrays
X_train,Y_train=np.array(X_train),np.array(Y_train)
#change to 2d array from 1d array
Y_train=Y_train.reshape(-1,4)
print(X_train.shape,Y_train.shape)

X_validate,Y_validate=np.array(X_validate),np.array(Y_validate)
Y_validate=Y_validate.reshape(-1,4)
print(X_validate.shape,Y_validate.shape)

X_train = Variable(torch.Tensor(X_train))
Y_train = Variable(torch.Tensor(Y_train))
print(X_train.shape,Y_train.shape)

X_validate = Variable(torch.Tensor(X_validate))
Y_validate = Variable(torch.Tensor(Y_validate))
print(X_validate.shape,Y_validate.shape)
# Out:
# (9789, 180, 4) (9789, 4)
# (1956, 180, 4) (1956, 4)
# torch.Size([9789, 180, 4]) torch.Size([9789, 4])
# torch.Size([1956, 180, 4]) torch.Size([1956, 4])

# %%
#Stacked lstm Network definition
class NETWORK_STACKED_LSTM(nn.Module):

    def __init__(self,num_classes,input_size,hidden_size,hidden_size2,num_layers):
        super(NETWORK_STACKED_LSTM,self).__init__()
        self.num_classes = num_classes
        self.num_layers = num_layers
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.hidden_size2 = hidden_size2
        self.lstm1=nn.LSTM(input_size=input_size, hidden_size=hidden_size,
                            num_layers=num_layers, batch_first=True).to(device)
        self.lstm2=nn.LSTM(input_size=hidden_size, hidden_size=hidden_size2,
                            num_layers=num_layers, batch_first=True).to(device)
        self.fc=nn.Linear(hidden_size2,num_classes)
    
    def forward(self,x):
        output_lstm1, (h_n,c_n) = self.lstm1(x)
        h_2 = h_n
        c_2 = c_n
        output_lstm2, (h_n,c_n) = self.lstm2(output_lstm1, (h_2, c_2))

        input_fc=output_lstm2[:,-1,:]
        output_fc=self.fc(input_fc).to(device)
        return output_fc

# %%
#Initializing model with parameters
num_epochs=250
learning_rate=0.01
input_size=4
hidden_size=3
hidden_size2=3
num_layers=1
num_classes=4

model=NETWORK_STACKED_LSTM(num_classes,input_size, hidden_size,hidden_size2,num_layers)
model.to(device)
# Out:
# NETWORK_STACKED_LSTM(
#   (lstm1): LSTM(4, 3, batch_first=True)
#   (lstm2): LSTM(3, 3, batch_first=True)
#   (fc): Linear(in_features=3, out_features=4, bias=True)
# )

# %%
# DEFINE OPTIMIZER
criterion = torch.nn.MSELoss()    # mean-squared error for regression
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
# Lists to store training losses for plotting the training curve
train_losses = []
valid_losses=[]
#batch gradient descent
# TRAIN THE MODEL:
for epoch in range(1,num_epochs+1):
    outputs = model(X_train.to(device))
    optimizer.zero_grad()
    # obtain the loss function
    loss = criterion(outputs, Y_train.to(device))
    loss.backward()
    optimizer.step()
    train_losses.append(loss.item())

    with torch.no_grad():
        valid_outputs=model(X_validate.to(device))
        valid_loss=criterion(valid_outputs,Y_validate.to(device))
        valid_losses.append(valid_loss.item())
    if epoch % 1 == 0:
        print("Epoch: %d, training loss: %1.5f, validation loss: %1.5f" % (epoch, loss.item(),valid_loss.item()))
# Out:
# Epoch: 1, training loss: 0.48546, validation loss: 0.43373
# Epoch: 2, training loss: 0.44810, validation loss: 0.40181
# Epoch: 3, training loss: 0.41510, validation loss: 0.37299
# Epoch: 4, training loss: 0.38542, validation loss: 0.34674
# Epoch: 5, training loss: 0.35844, validation loss: 0.32257
# Epoch: 6, training loss: 0.33363, validation loss: 0.30008
# Epoch: 7, training loss: 0.31056, validation loss: 0.27898
# Epoch: 8, training loss: 0.28894, validation loss: 0.25907
# Epoch: 9, training loss: 0.26854, validation loss: 0.24021
# Epoch: 10, training loss: 0.24924, validation loss: 0.22232
# Epoch: 11, training loss: 0.23095, validation loss: 0.20537
# Epoch: 12, training loss: 0.21362, validation loss: 0.18934
# Epoch: 13, training loss: 0.19725, validation loss: 0.17425
# Epoch: 14, training loss: 0.18184, validation loss: 0.16015
# Epoch: 15, training loss: 0.16745, validation loss: 0.14707
# Epoch: 16, training loss: 0.15410, validation loss: 0.13507
# Epoch: 17, training loss: 0.14186, validation loss: 0.12418
# Epoch: 18, training loss: 0.13073, validation loss: 0.11440
# Epoch: 19, training loss: 0.12073, validation loss: 0.10568
# Epoch: 20, training loss: 0.11181, validation loss: 0.09795
# Epoch: 21, training loss: 0.10389, validation loss: 0.09111
# Epoch: 22, training loss: 0.09688, validation loss: 0.08506
# Epoch: 23, training loss: 0.09066, validation loss: 0.07970
# Epoch: 24, training loss: 0.08515, validation loss: 0.07494
# Epoch: 25, training loss: 0.08025, validation loss: 0.07073
# Epoch: 26, training loss: 0.07590, validation loss: 0.06699
# Epoch: 27, training loss: 0.07203, validation loss: 0.06367
# Epoch: 28, training loss: 0.06857, validation loss: 0.06072
# Epoch: 29, training loss: 0.06548, validation loss: 0.05810
# Epoch: 30, training loss: 0.06272, validation loss: 0.05577
# Epoch: 31, training loss: 0.06023, validation loss: 0.05369
# Epoch: 32, training loss: 0.05799, validation loss: 0.05185
# Epoch: 33, training loss: 0.05597, validation loss: 0.05023
# Epoch: 34, training loss: 0.05416, validation loss: 0.04881
# Epoch: 35, training loss: 0.05254, validation loss: 0.04758
# Epoch: 36, training loss: 0.05110, validation loss: 0.04653
# Epoch: 37, training loss: 0.04985, validation loss: 0.04566
# Epoch: 38, training loss: 0.04878, validation loss: 0.04495
# Epoch: 39, training loss: 0.04787, validation loss: 0.04439
# Epoch: 40, training loss: 0.04712, validation loss: 0.04396
# Epoch: 204, training loss: 0.01385, validation loss: 0.01355
# Epoch: 205, training loss: 0.01359, validation loss: 0.01334
# Epoch: 206, training loss: 0.01333, validation loss: 0.01314
# Epoch: 207, training loss: 0.01309, validation loss: 0.01295
# Epoch: 208, training loss: 0.01285, validation loss: 0.01277
# Epoch: 209, training loss: 0.01261, validation loss: 0.01259
# Epoch: 210, training loss: 0.01238, validation loss: 0.01241
# Epoch: 211, training loss: 0.01216, validation loss: 0.01223
# Epoch: 212, training loss: 0.01194, validation loss: 0.01207
# Epoch: 213, training loss: 0.01173, validation loss: 0.01191
# Epoch: 214, training loss: 0.01153, validation loss: 0.01175
# Epoch: 215, training loss: 0.01133, validation loss: 0.01160
# Epoch: 216, training loss: 0.01115, validation loss: 0.01145
# Epoch: 217, training loss: 0.01098, validation loss: 0.01130
# Epoch: 218, training loss: 0.01082, validation loss: 0.01115
# Epoch: 219, training loss: 0.01066, validation loss: 0.01101
# Epoch: 220, training loss: 0.01052, validation loss: 0.01087
# Epoch: 221, training loss: 0.01038, validation loss: 0.01074
# Epoch: 222, training loss: 0.01025, validation loss: 0.01062
# Epoch: 223, training loss: 0.01014, validation loss: 0.01051
# Epoch: 224, training loss: 0.01003, validation loss: 0.01041
# Epoch: 225, training loss: 0.00993, validation loss: 0.01032
# Epoch: 226, training loss: 0.00985, validation loss: 0.01024
# Epoch: 227, training loss: 0.00977, validation loss: 0.01017
# Epoch: 228, training loss: 0.00970, validation loss: 0.01012
# Epoch: 229, training loss: 0.00964, validation loss: 0.01007
# Epoch: 230, training loss: 0.00959, validation loss: 0.01004
# Epoch: 231, training loss: 0.00954, validation loss: 0.01001
# Epoch: 232, training loss: 0.00950, validation loss: 0.00999
# Epoch: 233, training loss: 0.00946, validation loss: 0.00998
# Epoch: 234, training loss: 0.00943, validation loss: 0.00997
# Epoch: 235, training loss: 0.00940, validation loss: 0.00996
# Epoch: 236, training loss: 0.00938, validation loss: 0.00996
# Epoch: 237, training loss: 0.00935, validation loss: 0.00996
# Epoch: 238, training loss: 0.00933, validation loss: 0.00996
# Epoch: 239, training loss: 0.00932, validation loss: 0.00995
# Epoch: 240, training loss: 0.00930, validation loss: 0.00995
# Epoch: 241, training loss: 0.00929, validation loss: 0.00993
# Epoch: 242, training loss: 0.00927, validation loss: 0.00992
# Epoch: 243, training loss: 0.00925, validation loss: 0.00991
# Epoch: 244, training loss: 0.00924, validation loss: 0.00989
# Epoch: 245, training loss: 0.00922, validation loss: 0.00987
# Epoch: 246, training loss: 0.00921, validation loss: 0.00986
# Epoch: 247, training loss: 0.00919, validation loss: 0.00984
# Epoch: 248, training loss: 0.00917, validation loss: 0.00982
# Epoch: 249, training loss: 0.00915, validation loss: 0.00981
# Epoch: 250, training loss: 0.00914, validation loss: 0.00979

# %%
# Plotting the training curve
epochs=range(1,num_epochs+1)
st=0;end=50
plt.plot( epochs[st:end],train_losses[st:end], label='Training Loss')
plt.plot(epochs[st:end],valid_losses[st:end], label='Validation Loss')
# plt.plot(epochs, train_losses, label='Training Loss')
# plt.plot(epochs, valid_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE Loss')
plt.legend()
plt.show()

# %%
torch.save(model.state_dict(),'./assets/trained models state/stacked_lstm_state.pt')
